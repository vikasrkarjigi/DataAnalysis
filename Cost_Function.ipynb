# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasrkarjigi/DataAnalysis/blob/main/Cost_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cost Function**

# %%
import numpy as np
import matplotlib.pyplot as plt
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0,500.0])

# %%
def compute_cost(x,y,w,b):
  m = x.shape[0]
  cost_sum = 0
  for i in range(m):
    f_wb = w*x[i] + b
    cost = (f_wb - y[i])**2
    cost_sum = cost_sum +cost
  total_cost = (1/(2*m))*cost_sum

  return total_cost

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
plt_intuition(x_train, y_train)
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %%
x_train = np.array([1.0, 1.7, 2.0, 2.5, 3.0, 3.2])
y_train = np.array([250, 300, 480,  430,   630, 730,])

# %%
plt.close('all')
fig, ax, dyn_items = plt_stationary(x_train, y_train)
updater = plt_update_onclick(fig, ax, x_train, y_train, dyn_items)

# %%
soup_bowl()
